# %% [markdown]
# # 2603646_DataVisualization

# %% [markdown]
# ---
# * Author:  [Yuttapong Mahasittiwat](mailto:khala1391@gmail.com)
# * Technologist | Data Modeler | Data Analyst
# * [YouTube](https://www.youtube.com/khala1391)
# * [LinkedIn](https://www.linkedin.com/in/yuttapong-m/)
# ---

# %% [markdown]
# Source: [kaggle](https://www.kaggle.com/datasets/tmcketterick/job-prestige/data)

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import altair as alt
print("pandas version :",pd.__version__)
print("numpy version :",np.__version__)
print("matplotlib version :",mpl.__version__)
print("seaborn version :",sns.__version__)
print("altair version :",alt.__version__)
# Out:
# pandas version : 2.2.1
# numpy version : 1.26.4
# matplotlib version : 3.8.4
# seaborn version : 0.13.2
# altair version : 5.0.1

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning, message="the convert_dtype parameter is deprecated")

# %%
df = pd.read_csv('data/professions_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   job        102 non-null    object
#  1   education  102 non-null    float64
#  2   income     102 non-null    int64
#  3   women      102 non-null    float64
#  4   prestige   102 non-null    float64
#  5   census     102 non-null    int64
#  6   type       98 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.7+ KB

# %%
df
# Out:
#                      job  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753   0.00      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
alt.Chart(df).mark_bar().encode(
    x='type',
    y='prestige'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle().encode(
    x='education',
    y='prestige',
    color='type',
    size='income'
)
# Out:
# alt.Chart(...)

# %%
# alt.*?
alt.*Chart?
# alt.Chart.mark*?
# Out:
# alt.Chart
# alt.ConcatChart
# alt.FacetChart
# alt.HConcatChart
# alt.LayerChart
# alt.RepeatChart
# alt.VConcatChart

# %% [markdown]
# ## Regression

# %%
alt.Chart(df).mark_circle().encode(
    x='education',
    y='prestige',
    color='type:N',
    tooltip='income'
)
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart(df).mark_circle().encode(
    x= alt.X('education',scale=alt.Scale(domain=[0, 20])),
    y='prestige',
    color='type',
    tooltip=['income'],
)
chart+chart.transform_regression('education','prestige').mark_line()
# Out:
# alt.LayerChart(...)

# %%
educationPlot = alt.Chart(df).mark_circle().encode(
    x= alt.X('education',scale=alt.Scale(domain=[0, 20])),
    y='prestige',
    color='type',
)
incomePlot = alt.Chart(df).mark_circle().encode(
    x='income',
    y='prestige',
    color='type',
)

educationPlot | incomePlot
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## HTML interactive plot

# %%
df.columns
# Out:
# Index(['job', 'education', 'income', 'women', 'prestige', 'census', 'type'], dtype='object')

# %%
interact_plot = alt.Chart(df).mark_circle().encode(
    x='education',
    y='prestige',
    color='type',
    tooltip=['income','census'],
)
interact_plot.save('figure/interact_plot.html',
                   embed_options={'renderer':'svg',
                                 'actions':False})

# %%
interact_plot
# Out:
# alt.Chart(...)

# %%
interact_plot2 = alt.Chart(df).mark_circle().encode(
    x='education',
    y='prestige',
    color='type',
    size='income',
    tooltip=['census'],
)
interact_plot2
# Out:
# alt.Chart(...)
