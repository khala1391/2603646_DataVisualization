# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('data/demox.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   month     430 non-null    int64
#  1   brand     430 non-null    object
#  2   1300cc    430 non-null    int64
#  3   1600cc    430 non-null    int64
#  4   1800cc    430 non-null    int64
#  5   2000cc    430 non-null    int64
#  6   gt2000cc  430 non-null    int64
#  7   elec      430 non-null    int64
#  8   total     430 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 30.4+ KB
#    month       brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  total
# 0      1  ALFA ROMEO       0       0       0       0         1     0      1
# 1      1        AUDI       0       2       0      14         0     0     16
# 2      1     BENTLEY       0       0       0       0         2     0      2
# 3      1         BMW       1      45       0     586        64     0    696
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# NISSAN           12
# KIA              12
# TOYOTA           12
# SUZUKI           12
# SUBARU           12
# PROTON           12
# PORSCHE          12
# AUDI             12
# MITSUBISHI       12
# MINI COOPER      12
# MG               12
# MERCEDES BENZ    12
# MAZDA            12
# VOLVO            12
# LEXUS            12
# VOLKSWAGEN       12
# BMW              12
# ISUZU            12
# HYUNDAI          12
# HONDA            12
# FORD             12
# CHEVROLET        12
# LAND ROVER       11
# TATA             11
# RANGE ROVER      11
# PEUGEOT          11
# FERRARI          11
# อื่น ๆ           11
# JAGUAR           11
# LAMBORGHINI      10
# ROLLS-ROYCE       9
# BENTLEY           8
# JEEP              7
# ASTON MARTIN      7
# MASERATI          7
# ALFA ROMEO        6
# FIAT              6
# CADILLAC          5
# SKODA             4
# SSANGYONG         4
# CITROEN           4
# CHERY             2
# MITSUOKA          2
# DAIHATSU          2
# NAZA              2
# ...

# %%
df['month'].value_counts().sort_index()
# Out:
# month
# 1     37
# 2     38
# 3     34
# 4     34
# 5     37
# 6     38
# 7     39
# 8     38
# 9     33
# 10    34
# 11    33
# 12    35
# Name: count, dtype: int64

# %%
# df.select_dtypes(inlude='object')
# Out:
# Index(['month', 'brand', '1300cc', '1600cc', '1800cc', '2000cc', 'gt2000cc',
#        'elec', 'total'],
#       dtype='object')

# %%
top10 = list(df.brand.value_counts().head(10).index)
top10
# Out:
# ['NISSAN',
#  'KIA',
#  'TOYOTA',
#  'SUZUKI',
#  'SUBARU',
#  'PROTON',
#  'PORSCHE',
#  'AUDI',
#  'MITSUBISHI',
#  'MINI COOPER']

# %%
df_top10 = df[df['brand'].isin(['NISSAN',
                     'KIA',
                     'TOYOTA',
                     'SUZUKI',
                     'SUBARU',
                     'PROTON',
                     'PORSCHE',
                     'AUDI',
                     'MITSUBISHI',
                     'MINI COOPER'])]

# %%
df_top10
# Out:
#      month        brand  1300cc  1600cc  1800cc  2000cc  gt2000cc  elec  total
# 1        1         AUDI       0       2       0      14         0     0     16
# 14       1          KIA       2       7       0       0         1     0     10
# 22       1  MINI COOPER       0      55       0      64         0     0    119
# 23       1   MITSUBISHI    1244       0       6      21      4658     0   5929
# 24       1       NISSAN    1542     572      50     573       549     0   3286
# ..     ...          ...     ...     ...     ...     ...       ...   ...    ...
# 420     12      PORSCHE       0       0       0      10        29     0     39
# 421     12       PROTON       0       6       0       0         0     0      6
# 423     12       SUBARU       0       2       0     161         3     0    166
# 424     12       SUZUKI    1043      54       0       0         0     0   1097
# 426     12       TOYOTA    1635    1908     681     198      3561     0   7983
#
# [120 rows x 9 columns]

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning, message="the convert_dtype parameter is deprecated")

# %%
alt.Chart(df_top10).mark_bar().encode(
    x = 'brand',
    y = 'total'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_rect().encode(
    x='1600cc',
    y='1300cc',
    color='total'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart.mark*?
# Out:
# alt.Chart.mark_arc
# alt.Chart.mark_area
# alt.Chart.mark_bar
# alt.Chart.mark_boxplot
# alt.Chart.mark_circle
# alt.Chart.mark_errorband
# alt.Chart.mark_errorbar
# alt.Chart.mark_geoshape
# alt.Chart.mark_image
# alt.Chart.mark_line
# alt.Chart.mark_point
# alt.Chart.mark_rect
# alt.Chart.mark_rule
# alt.Chart.mark_square
# alt.Chart.mark_text
# alt.Chart.mark_tick
# alt.Chart.mark_trail
